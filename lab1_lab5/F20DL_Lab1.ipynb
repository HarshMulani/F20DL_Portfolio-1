# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Our Datasets
#
# https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
#
# https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification
#
# https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset

# %% [markdown]
# 1. BreastCancer Dataset

# %%
dataset1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/F20DL_datasets/BreastCancer/data.csv')
dataset1.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# We can see by observing that the
# - 'id' is not relevant to our task
# - 'diagnice' holds the value of our class
# - 'Unnamed:32' includes the null value

# %%
dataset1.drop(['id', 'Unnamed: 32'], axis = 1, inplace = True)

# %%
dataset1.info
# Out:
# <bound method DataFrame.info of     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# In our dataset1, we have 32 features (columns).
# The data involves 570 patients
# The outcome we need to predict is M (malignant) / B (benign).
#
# Both malignant and benign are tumors composed of the same type of cells, although malignant can spread to other parts of the body because its cells can move, while benign cells stay in only one location or place. Therefore, in another language, we can say that we will predict whether the cancer will spread or not.

# %% [markdown]
# 2. HouseRent Dataset

# %%
dataset2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/F20DL_datasets/HouseRent/House_Rent_Dataset.csv')
dataset2.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %% [markdown]
# In this Dataset, we have information on almost 4700+ Houses/Apartments/Flats Available for Rent with different parameters like BHK, Rent, Size...

# %%
dataset2.info
# Out:
# <bound method DataFrame.info of        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# ...

# %%
dataset2["Floor"].value_counts()
# Out:
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
#                   ...
# 11 out of 31         1
# 50 out of 75         1
# 18 out of 26         1
# 12 out of 27         1
# 23 out of 34         1
# Name: Floor, Length: 480, dtype: int64

# %% [markdown]
# More than 400 unique values have been observed in the Floor data. For a more efficient analysis, it will be useful to divide this data into two columns as the 'Rental Floor' and the 'Total Number of Floors'.

# %% [markdown]
# 3. MobilePrice Dataset

# %%
dataset3_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/F20DL_datasets/MobilePrice/train.csv')
dataset3_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dataset3_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/F20DL_datasets/MobilePrice/test.csv')
dataset3_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
dataset3_train.info
# Out:
# <bound method DataFrame.info of       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
# ...

# %%
dataset3_train.isnull().any()
# Out:
# battery_power    False
# blue             False
# clock_speed      False
# dual_sim         False
# fc               False
# four_g           False
# int_memory       False
# m_dep            False
# mobile_wt        False
# n_cores          False
# pc               False
# px_height        False
# px_width         False
# ram              False
# sc_h             False
# sc_w             False
# talk_time        False
# three_g          False
# touch_screen     False
# wifi             False
# price_range      False
# dtype: bool

# %% [markdown]
# We can find that this is a very clean training dataset with no missing pieces. We want to find some relationship between the features of a phone (e.g., memory, internal storage, etc.) and its selling price. So for this dataset we can predict the price range of the phone very well.
